# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

from pycaret.classification import *
import ast
import plotly.graph_objects as go
import plotly.express as px
import seaborn as sns

# %%
train = pd.read_csv('train_data')
test = pd.read_csv('test_data')

# %%
s = setup(data=train,
          target= 'Disease',
          experiment_name='DiseasePrediction'
          )
# Out:
# <style type="text/css">
# #T_79889_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_79889">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79889_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_79889_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79889_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79889_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_79889_row0_col1" class="data row0 col1" >2477</td>
#     </tr>
#     <tr>
#       <th id="T_79889_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_79889_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_79889_row1_col1" class="data row1 col1" >Disease</td>
#     </tr>
#     <tr>
#       <th id="T_79889_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# # Compare Model

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_a4009 th {
#   text-align: left;
# }
# ...

# %%
metrics = get_metrics()

# %%
metrics
# Out:
#                 Name Display Name  \
# ID
# acc         Accuracy     Accuracy
# auc              AUC          AUC
# recall        Recall       Recall
# precision  Precision        Prec.
# f1                F1           F1
# kappa          Kappa        Kappa
# mcc              MCC          MCC
#
#                                               Score Function  \
# ID
# acc          <function accuracy_score at 0x00000257F4FD0940>
# auc        <pycaret.internal.metrics.BinaryMulticlassScor...
# recall     <pycaret.internal.metrics.BinaryMulticlassScor...
# precision  <pycaret.internal.metrics.BinaryMulticlassScor...
# f1         <pycaret.internal.metrics.BinaryMulticlassScor...
# kappa      <function cohen_kappa_score at 0x00000257F4FD0...
# mcc        <function matthews_corrcoef at 0x00000257F4FD0...
#
#                                                       Scorer      Target  \
# ID
# acc                                                 accuracy        pred
# ...

# %% [markdown]
# # Evaluate Model

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
finalized_model = finalize_model(best_model)

# %% [markdown]
# # Finalize and Predict Model

# %%
predict_model(finalized_model,data=test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a8559">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8559_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a8559_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a8559_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a8559_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a8559_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a8559_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a8559_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a8559_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8559_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8559_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
# ...

# %%
type(best_model)
# Out:
# sklearn.tree._classes.DecisionTreeClassifier

# %% [markdown]
# # Random Forest

# %%
rf=create_model('rf')
# Out:
# <style type="text/css">
# #T_09af1_row10_col0, #T_09af1_row10_col1, #T_09af1_row10_col2, #T_09af1_row10_col3, #T_09af1_row10_col4, #T_09af1_row10_col5, #T_09af1_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_09af1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09af1_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_09af1_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_09af1_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_09af1_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_09af1_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_09af1_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_09af1_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
predict_model(rf,data=test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d1c82">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1c82_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d1c82_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d1c82_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d1c82_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d1c82_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d1c82_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d1c82_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d1c82_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1c82_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d1c82_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
# ...

# %% [markdown]
# # LightBGM

# %%
lightgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_a024f_row10_col0, #T_a024f_row10_col1, #T_a024f_row10_col2, #T_a024f_row10_col3, #T_a024f_row10_col4, #T_a024f_row10_col5, #T_a024f_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a024f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a024f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a024f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a024f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a024f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a024f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a024f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a024f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
predict_model(lightgbm,data=test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3766c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3766c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3766c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3766c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3766c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3766c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3766c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3766c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3766c_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3766c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3766c_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
# ...

# %% [markdown]
# # xgboost

# %%
xgboost = create_model('xgboost')
# Out:
# <style type="text/css">
# #T_74688_row10_col0, #T_74688_row10_col1, #T_74688_row10_col2, #T_74688_row10_col3, #T_74688_row10_col4, #T_74688_row10_col5, #T_74688_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_74688">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74688_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_74688_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_74688_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_74688_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_74688_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_74688_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_74688_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
predict_model(xgboost,data=test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e0270">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0270_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e0270_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e0270_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e0270_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e0270_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e0270_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e0270_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e0270_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0270_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0270_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
# ...
